# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s=pd.read_csv("FitBit data.csv")

# %%
s
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
s.shape
# Out:
# (457, 15)

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %%
s.isna().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
s.describe().T
# Out:
#                           count          mean           std           min  \
# Id                        457.0  4.628595e+09  2.293781e+09  1.503960e+09
# TotalSteps                457.0  6.546562e+03  5.398493e+03  0.000000e+00
# TotalDistance             457.0  4.663523e+00  4.082072e+00  0.000000e+00
# TrackerDistance           457.0  4.609847e+00  4.068540e+00  0.000000e+00
# LoggedActivitiesDistance  457.0  1.794274e-01  8.492318e-01  0.000000e+00
# VeryActiveDistance        457.0  1.180897e+00  2.487159e+00  0.000000e+00
# ModeratelyActiveDistance  457.0  4.786433e-01  8.309952e-01  0.000000e+00
# LightActiveDistance       457.0  2.890197e+00  2.237523e+00  0.000000e+00
# SedentaryActiveDistance   457.0  1.903720e-03  8.486801e-03  0.000000e+00
# VeryActiveMinutes         457.0  1.662363e+01  2.891970e+01  0.000000e+00
# FairlyActiveMinutes       457.0  1.307002e+01  3.620864e+01  0.000000e+00
# LightlyActiveMinutes      457.0  1.700700e+02  1.222054e+02  0.000000e+00
# ...

# %%
s["Id"].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
s["Id"].nunique()
# Out:
# 35

# %%
s["Id"].duplicated().sum()
# Out:
# 422

# %%
s.duplicated().sum()
# Out:
# 0

# %%
s["LoggedActivitiesDistance"].value_counts()
# Out:
# 0.000000    433
# 2.092147      4
# 2.253081      3
# 1.609344      1
# 5.189850      1
# 3.218688      1
# 4.869783      1
# 4.842320      1
# 4.875990      1
# 4.835720      1
# 4.836380      1
# 4.901283      1
# 0.055843      1
# 4.828032      1
# 5.456864      1
# 1.926302      1
# 3.972795      1
# 6.727057      1
# 2.027773      1
# 2.696455      1
# Name: LoggedActivitiesDistance, dtype: int64

# %%
s.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
s["Calories"].agg(["max","min","mean","median"])
# Out:
# max       4562.000000
# min          0.000000
# mean      2189.452954
# median    2062.000000
# Name: Calories, dtype: float64

# %%
s[s["Calories"]==4562][["ActivityDate"]].value_counts()
# Out:
# ActivityDate
# 4/1/2016        1
# dtype: int64

# %%
s[s["Calories"]==0][["ActivityDate"]].value_counts()
# Out:
# ActivityDate
# 4/12/2016       3
# 4/10/2016       1
# 4/9/2016        1
# dtype: int64

# %%
s[s["Calories"]==2062][["ActivityDate"]].value_counts()
# Out:
# ActivityDate
# 4/9/2016        1
# dtype: int64

# %%
s["TotalSteps"].agg(["max","min","mean","median"])
# Out:
# max       28497.000000
# min           0.000000
# mean       6546.562363
# median     5986.000000
# Name: TotalSteps, dtype: float64

# %%
s[s["TotalSteps"]==28497]["Calories"].value_counts()
# Out:
# 4526    1
# Name: Calories, dtype: int64

# %%
s[s["TotalSteps"]==5986]["Calories"].value_counts()
# Out:
# 2297    1
# Name: Calories, dtype: int64

# %%
s["TotalDistance"]=s["TotalDistance"].apply(lambda x:round(x,2))
s
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004           7.11         7.110000
# 1    1503960366    3/26/2016       17609          11.55        11.550000
# 2    1503960366    3/27/2016       12736           8.53         8.530000
# 3    1503960366    3/28/2016       13231           8.93         8.930000
# 4    1503960366    3/29/2016       12041           7.85         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014          20.39        20.389999
# 453  8877689391     4/9/2016       16470           8.07         8.070000
# 454  8877689391    4/10/2016       28497          27.53        27.530001
# 455  8877689391    4/11/2016       10622           8.06         8.060000
# 456  8877689391    4/12/2016        2350           1.78         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
s["TrackerDistance"]=s["TrackerDistance"].apply(lambda x:round(x,2))
s
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004           7.11             7.11
# 1    1503960366    3/26/2016       17609          11.55            11.55
# 2    1503960366    3/27/2016       12736           8.53             8.53
# 3    1503960366    3/28/2016       13231           8.93             8.93
# 4    1503960366    3/29/2016       12041           7.85             7.85
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014          20.39            20.39
# 453  8877689391     4/9/2016       16470           8.07             8.07
# 454  8877689391    4/10/2016       28497          27.53            27.53
# 455  8877689391    4/11/2016       10622           8.06             8.06
# 456  8877689391    4/12/2016        2350           1.78             1.78
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
s["TotalDistance"].agg(["max","min","mean","median"])
# Out:
# max       27.530000
# min        0.000000
# mean       4.663523
# median     4.090000
# Name: TotalDistance, dtype: float64

# %%
s.sort_values(["ActivityDate"],inplace=True)

# %%
s
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 197  4057192912    3/12/2016           0           0.00             0.00
# 165  4020332650    3/12/2016        5543           3.97             3.97
# 166  4020332650    3/13/2016        3226           2.31             2.31
# 198  4057192912    3/13/2016           0           0.00             0.00
# 167  4020332650    3/14/2016        3023           2.17             2.17
# ..          ...          ...         ...            ...              ...
# 272  4558609924     4/9/2016        5512           3.64             3.64
# 260  4445114986     4/9/2016        4195           2.81             2.81
# 421  8378563200     4/9/2016        2240           1.78             1.78
# 386  7086361926     4/9/2016        7338           4.67             4.67
# 161  3977333714     4/9/2016       14583           9.76             9.76
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
s["ActivityDate"].iloc[0]
# Out:
# '3/12/2016'

# %%
s["ActivityDate"].iloc[-1]
# Out:
# '4/9/2016'

# %%
s.reset_index(inplace=True)
s
# Out:
#      index          Id ActivityDate  TotalSteps  TotalDistance  \
# 0      197  4057192912    3/12/2016           0           0.00
# 1      165  4020332650    3/12/2016        5543           3.97
# 2      166  4020332650    3/13/2016        3226           2.31
# 3      198  4057192912    3/13/2016           0           0.00
# 4      167  4020332650    3/14/2016        3023           2.17
# ..     ...         ...          ...         ...            ...
# 452    272  4558609924     4/9/2016        5512           3.64
# 453    260  4445114986     4/9/2016        4195           2.81
# 454    421  8378563200     4/9/2016        2240           1.78
# 455    386  7086361926     4/9/2016        7338           4.67
# 456    161  3977333714     4/9/2016       14583           9.76
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0               0.00                       0.0                0.00
# 1               3.97                       0.0                0.00
# ...

# %%
s["ActivityDate"]=pd.to_datetime(s["ActivityDate"])
s
# Out:
#      index          Id ActivityDate  TotalSteps  TotalDistance  \
# 0      197  4057192912   2016-03-12           0           0.00
# 1      165  4020332650   2016-03-12        5543           3.97
# 2      166  4020332650   2016-03-13        3226           2.31
# 3      198  4057192912   2016-03-13           0           0.00
# 4      167  4020332650   2016-03-14        3023           2.17
# ..     ...         ...          ...         ...            ...
# 452    272  4558609924   2016-04-09        5512           3.64
# 453    260  4445114986   2016-04-09        4195           2.81
# 454    421  8378563200   2016-04-09        2240           1.78
# 455    386  7086361926   2016-04-09        7338           4.67
# 456    161  3977333714   2016-04-09       14583           9.76
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0               0.00                       0.0                0.00
# 1               3.97                       0.0                0.00
# ...

# %%
s.drop(columns=["index"],inplace=True)

# %%
s
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    4057192912   2016-03-12           0           0.00             0.00
# 1    4020332650   2016-03-12        5543           3.97             3.97
# 2    4020332650   2016-03-13        3226           2.31             2.31
# 3    4057192912   2016-03-13           0           0.00             0.00
# 4    4020332650   2016-03-14        3023           2.17             2.17
# ..          ...          ...         ...            ...              ...
# 452  4558609924   2016-04-09        5512           3.64             3.64
# 453  4445114986   2016-04-09        4195           2.81             2.81
# 454  8378563200   2016-04-09        2240           1.78             1.78
# 455  7086361926   2016-04-09        7338           4.67             4.67
# 456  3977333714   2016-04-09       14583           9.76             9.76
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
s["month"]=s["ActivityDate"].apply(lambda x:x.month)
s["day"]=s["ActivityDate"].apply(lambda x:x.day)
s["year"]=s["ActivityDate"].apply(lambda x:x.year)

# %%
s
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    4057192912   2016-03-12           0           0.00             0.00
# 1    4020332650   2016-03-12        5543           3.97             3.97
# 2    4020332650   2016-03-13        3226           2.31             2.31
# 3    4057192912   2016-03-13           0           0.00             0.00
# 4    4020332650   2016-03-14        3023           2.17             2.17
# ..          ...          ...         ...            ...              ...
# 452  4558609924   2016-04-09        5512           3.64             3.64
# 453  4445114986   2016-04-09        4195           2.81             2.81
# 454  8378563200   2016-04-09        2240           1.78             1.78
# 455  7086361926   2016-04-09        7338           4.67             4.67
# 456  3977333714   2016-04-09       14583           9.76             9.76
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
plt.boxplot(s["Calories"]);

# %%
s["Calories"].describe()
# Out:
# count     457.000000
# mean     2189.452954
# std       815.484523
# min         0.000000
# 25%      1776.000000
# 50%      2062.000000
# 75%      2667.000000
# max      4562.000000
# Name: Calories, dtype: float64

# %%
iqr=2667.000000-1776.000000
iqr
# Out:
# 891.0

# %%
1776.000000-1.5*891.0
# Out:
# 439.5

# %%
extreamly_low=s[s["Calories"]<439.5]

# %%
extreamly_low
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 129  6117666160   2016-04-10           0           0.00             0.00
# 168  4702921684   2016-04-12           0           0.00             0.00
# 173  8253242879   2016-04-12           0           0.00             0.00
# 176  1844505072   2016-04-12           0           0.00             0.00
# 179  2873212765   2016-04-12           0           0.00             0.00
# 182  3977333714   2016-04-12         759           0.57             0.57
# 183  1503960366   2016-04-12         224           0.14             0.14
# 185  2347167796   2016-04-12           0           0.00             0.00
# 425  4319703577   2016-04-09           0           0.00             0.00
# 447  6391747486   2016-04-09           0           0.00             0.00
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 129                       0.0                 0.0                       0.0
# ...

# %%
iqr=2667.000000-1776.000000
iqr
# Out:
# 891.0

# %%
2667.000000+1.5*891.0
# Out:
# 4003.5

# %%
extremly_high=s[s["Calories"]>4003.5]

# %%
extremly_high
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 40   4020332650   2016-03-28        2106           1.51             1.51
# 101  2891001357   2016-04-01           0           0.00             0.00
# 109  8877689391   2016-04-10       28497          27.53            27.53
# 187  5577150313   2016-04-02       14873          11.11            11.11
# 199  8877689391   2016-04-02       27572          23.39            23.39
# 206  1644430081   2016-04-02       20237          14.71            14.71
# 290  8378563200   2016-04-04       13935          11.05            11.05
# 309  6775888955   2016-04-05        9348           6.70             6.70
# 314  8378563200   2016-04-05       12846          10.19            10.19
# 330  8877689391   2016-04-06       24136          20.91            20.91
# 407  4020332650   2016-04-08       10480           7.51             7.51
# 408  8877689391   2016-04-08       23014          20.39            20.39
#
# ...

# %%
s["year"].value_counts()
# Out:
# 2016    457
# Name: year, dtype: int64

# %%
s["month"].value_counts()
# Out:
# 4    383
# 3     74
# Name: month, dtype: int64

# %%
plt.hist(s["month"]);

# %%
s["day"].agg(["max","min"])
# Out:
# max    31
# min     1
# Name: day, dtype: int64

# %%
plt.bar(s["day"],s["Calories"])
# Out:
# <BarContainer object of 457 artists>

# %%
s.groupby(["TotalDistance"])["day"].value_counts()
# Out:
# TotalDistance  day
# 0.00           4      9
#                3      8
#                1      6
#                12     6
#                5      5
#                      ..
# 20.14          3      1
# 20.39          8      1
# 20.91          6      1
# 23.39          2      1
# 27.53          10     1
# Name: day, Length: 408, dtype: int64

# %%
plt.scatter(s["day"],s["TotalDistance"])

# %%
s.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'month', 'day',
#        'year'],
#       dtype='object')

# %%
s[["TotalDistance","TrackerDistance"]]
# Out:
#      TotalDistance  TrackerDistance
# 0             0.00             0.00
# 1             3.97             3.97
# 2             2.31             2.31
# 3             0.00             0.00
# 4             2.17             2.17
# ..             ...              ...
# 452           3.64             3.64
# 453           2.81             2.81
# 454           1.78             1.78
# 455           4.67             4.67
# 456           9.76             9.76
#
# [457 rows x 2 columns]

# %%
s.drop(columns=["TrackerDistance"],inplace=True)

# %%
s
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  \
# 0    4057192912   2016-03-12           0           0.00
# 1    4020332650   2016-03-12        5543           3.97
# 2    4020332650   2016-03-13        3226           2.31
# 3    4057192912   2016-03-13           0           0.00
# 4    4020332650   2016-03-14        3023           2.17
# ..          ...          ...         ...            ...
# 452  4558609924   2016-04-09        5512           3.64
# 453  4445114986   2016-04-09        4195           2.81
# 454  8378563200   2016-04-09        2240           1.78
# 455  7086361926   2016-04-09        7338           4.67
# 456  3977333714   2016-04-09       14583           9.76
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                0.00                      0.00
# 1                         0.0                0.00                      0.00
# ...

# %%
s.set_index("ActivityDate",inplace=True)

# %%
s
# Out:
#                       Id  TotalSteps  TotalDistance  LoggedActivitiesDistance  \
# ActivityDate
# 2016-03-12    4057192912           0           0.00                       0.0
# 2016-03-12    4020332650        5543           3.97                       0.0
# 2016-03-13    4020332650        3226           2.31                       0.0
# 2016-03-13    4057192912           0           0.00                       0.0
# 2016-03-14    4020332650        3023           2.17                       0.0
# ...                  ...         ...            ...                       ...
# 2016-04-09    4558609924        5512           3.64                       0.0
# 2016-04-09    4445114986        4195           2.81                       0.0
# 2016-04-09    8378563200        2240           1.78                       0.0
# 2016-04-09    7086361926        7338           4.67                       0.0
# 2016-04-09    3977333714       14583           9.76                       0.0
#
# ...

# %%
s.index[-1]-s.index[0]
# Out:
# Timedelta('28 days 00:00:00')

# %%
s["month"].unique()
# Out:
# array([3, 4], dtype=int64)

# %%
s.drop(columns=["LoggedActivitiesDistance","VeryActiveDistance","ModeratelyActiveDistance","LightActiveDistance"],inplace=True)

# %%
s.drop(columns=["SedentaryActiveDistance"],inplace=True)

# %%
s
# Out:
#                       Id  TotalSteps  TotalDistance  VeryActiveMinutes  \
# ActivityDate
# 2016-03-12    4057192912           0           0.00                  0
# 2016-03-12    4020332650        5543           3.97                  0
# 2016-03-13    4020332650        3226           2.31                  0
# 2016-03-13    4057192912           0           0.00                  0
# 2016-03-14    4020332650        3023           2.17                  0
# ...                  ...         ...            ...                ...
# 2016-04-09    4558609924        5512           3.64                  0
# 2016-04-09    4445114986        4195           2.81                  0
# 2016-04-09    8378563200        2240           1.78                  0
# 2016-04-09    7086361926        7338           4.67                 27
# 2016-04-09    3977333714       14583           9.76                 35
#
#               FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# ActivityDate
# ...

# %%
x=s["VeryActiveMinutes"]

# %%
y=s["FairlyActiveMinutes"]

# %%
a=s["LightlyActiveMinutes"]

# %%
a
# Out:
# ActivityDate
# 2016-03-12      0
# 2016-03-12    254
# 2016-03-13    136
# 2016-03-13      0
# 2016-03-14    145
#              ...
# 2016-04-09    276
# 2016-04-09    239
# 2016-04-09    110
# 2016-04-09    204
# 2016-04-09    254
# Name: LightlyActiveMinutes, Length: 457, dtype: int64

# %%
b=s["LightlyActiveMinutes"]

# %%
b
# Out:
# ActivityDate
# 2016-03-12      0
# 2016-03-12    254
# 2016-03-13    136
# 2016-03-13      0
# 2016-03-14    145
#              ...
# 2016-04-09    276
# 2016-04-09    239
# 2016-04-09    110
# 2016-04-09    204
# 2016-04-09    254
# Name: LightlyActiveMinutes, Length: 457, dtype: int64

# %%
s["Total"]=x+y+a+b

# %%
s
# Out:
#                       Id  TotalSteps  TotalDistance  VeryActiveMinutes  \
# ActivityDate
# 2016-03-12    4057192912           0           0.00                  0
# 2016-03-12    4020332650        5543           3.97                  0
# 2016-03-13    4020332650        3226           2.31                  0
# 2016-03-13    4057192912           0           0.00                  0
# 2016-03-14    4020332650        3023           2.17                  0
# ...                  ...         ...            ...                ...
# 2016-04-09    4558609924        5512           3.64                  0
# 2016-04-09    4445114986        4195           2.81                  0
# 2016-04-09    8378563200        2240           1.78                  0
# 2016-04-09    7086361926        7338           4.67                 27
# 2016-04-09    3977333714       14583           9.76                 35
#
#               FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# ActivityDate
# ...

# %%
s.groupby(["Id"])["Total"].value_counts()
# Out:
# Id          Total
# 1503960366  18       1
#             393      1
#             427      1
#             455      1
#             468      1
#                     ..
# 8877689391  641      1
#             660      1
#             677      1
#             739      1
#             817      1
# Name: Total, Length: 392, dtype: int64
