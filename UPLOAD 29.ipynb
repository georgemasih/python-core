# %% [markdown]
# Q1. Please generate a random float where the value is between 10 and 100 using Python math module.
# Hints: Use random.random() to generate a random float in [0,1].

# %%
import random

# %%
n=random.random()
for i in range(10,100):
    print(random.random())
# Out:
# 0.6710269630834994
# 0.57158609637354
# 0.10833490728970241
# 0.25616866433324403
# 0.6120312387384812
# 0.9025390236305627
# 0.6685258160273488
# 0.09991014033416645
# 0.5032843276968122
# 0.35341135097246534
# 0.37735319532677014
# 0.7377189089189428
# 0.7316223312174215
# 0.8941802221350864
# 0.006810185100743826
# 0.44432353186883267
# 0.8306148856102195
# 0.7835640087630298
# 0.17276700764887032
# 0.3237358599858918
# 0.4044574870080111
# 0.3708709124839842
# 0.48182443895300653
# 0.8054990666081291
# 0.12446914666856368
# 0.612375017489341
# 0.11822144248809574
# 0.294987924532348
# 0.9920759115370723
# 0.5328019903455388
# 0.8601397664551004
# 0.09061369456271429
# 0.9360288720482869
# 0.8583803184178177
# 0.8039807073905784
# 0.6155682116291026
# 0.759682864872241
# 0.11864545761180556
# 0.6726853974997161
# 0.9125119307151726
# 0.8124274550564617
# 0.003632265717735561
# 0.7252071723509544
# 0.9328841120174607
# 0.16807190934523764
# 0.4150942831529365
# 0.964392902554623
# ...

# %% [markdown]
# Q2. Please generate a random float where the value is between 5 and 95 using Python math module.
# Hints: Use random.random() to generate a random float in [0,1].

# %%
import random
s=random.random()
for i in range(5,95):
    print(random.random())
# Out:
# 0.5825467350469795
# 0.3991374443999005
# 0.3519201566492759
# 0.8034762436679594
# 0.020135918558489063
# 0.9088351792830608
# 0.5459832754070852
# 0.8644673233444787
# 0.35660718268021396
# 0.4293069409465281
# 0.11577754484581837
# 0.2759410616068798
# 0.796119468973282
# 0.2979476503209484
# 0.9229825628119148
# 0.9373209726474515
# 0.9830631060661477
# 0.23702470022174937
# 0.0851925712789694
# 0.23085602877013678
# 0.47885846292000067
# 0.1482310950866944
# 0.660589641784339
# 0.6248959202585284
# 0.44690636265318173
# 0.5327192830233045
# 0.06505034254827757
# 0.6995232078502391
# 0.10716492312237358
# 0.6921096258599264
# 0.9013807306035316
# 0.4229849923126644
# 0.759023733512501
# 0.7547381478847623
# 0.3536131460165508
# 0.17962006335972236
# 0.07103877211311982
# 0.38645997709437274
# 0.33400174797498317
# 0.9368165688597435
# 0.7909447806504252
# 0.5470762357460379
# 0.5694528955951119
# 0.2663981920742229
# 0.2307547117066907
# 0.04740808103934002
# 0.4937449927041171
# ...
